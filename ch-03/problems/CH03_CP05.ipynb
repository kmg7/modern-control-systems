# %%
import numpy as np
import control as ct
import display_utils as dp

# %%
A_1 =  np.array([[0, 1, 0], [0, 0, 1], [-4, -5, -8]])
B_1 =  np.array([[0], [0], [4]])
C_1 =  np.array([[1, 0, 0]])
D_1 =  np.array([[0]])

A_2 =  np.array([[0.5, 0.5, 0.7071], [-0.5, -0.5, 0.7071], [-6.3640, -0.7071, -8.0]])
B_2 =  np.array([[0], [0], [4]])
C_2 =  np.array([[0.7071, -0.7071, 0]])
D_2 =  np.array([[0]])

# %%
ss_A = ct.ss(A_1, B_1, C_1, D_1)
tf_A = ct.tf(ss_A)
dp.ss(ss_A)
dp.tf(tf_A)
# Out:
# ### State-Space System
# **System dimensions:** 3 states, 1 input(s), 1 output(s)
# **State-space equations:**
# $\displaystyle \dot{\mathbf{x}} = A\mathbf{x} + B\mathbf{u}$
# $\displaystyle \mathbf{y} = C\mathbf{x} + D\mathbf{u}$
# **System matrices:**
# $\displaystyle A = \left[\begin{matrix}0 & 1 & 0\\0 & 0 & 1\\-4 & -5 & -8\end{matrix}\right]$
# $\displaystyle B = \left[\begin{matrix}0\\0\\4\end{matrix}\right]$
# $\displaystyle C = \left[\begin{matrix}1 & 0 & 0\end{matrix}\right]$
# $\displaystyle D = \left[\begin{matrix}0\end{matrix}\right]$
# ### Transfer Function
# $\displaystyle G(s) = \frac{4}{s^{3} + 8s^{2} + 5s + 4}$

# %%
ss_B = ct.ss(A_2, B_2, C_2, D_2)
tf_B = ct.tf(ss_B)
dp.ss(ss_B)
dp.tf(tf_B)
# Out:
# ### State-Space System
# **System dimensions:** 3 states, 1 input(s), 1 output(s)
# **State-space equations:**
# $\displaystyle \dot{\mathbf{x}} = A\mathbf{x} + B\mathbf{u}$
# $\displaystyle \mathbf{y} = C\mathbf{x} + D\mathbf{u}$
# **System matrices:**
# $\displaystyle A = \left[\begin{matrix}\frac{1}{2} & \frac{1}{2} & \frac{7071}{10000}\\- \frac{1}{2} & - \frac{1}{2} & \frac{7071}{10000}\\- \frac{1591}{250} & - \frac{7071}{10000} & -8\end{matrix}\right]$
# $\displaystyle B = \left[\begin{matrix}0\\0\\4\end{matrix}\right]$
# $\displaystyle C = \left[\begin{matrix}\frac{7071}{10000} & - \frac{7071}{10000} & 0\end{matrix}\right]$
# $\displaystyle D = \left[\begin{matrix}0\end{matrix}\right]$
# ### Transfer Function
# $\displaystyle G(s) = \frac{3.99992}{s^{3} + 8s^{2} + 4.99997s + 3.99999}$

# %% [markdown]
# The state-space representation of a transfer function is not unique
