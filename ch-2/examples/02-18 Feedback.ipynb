# %%
import control as ct

g = ct.tf([1], [500, 0, 0])
h = ct.tf([1, 1], [1, 2])

sys = ct.feedback(g, h)
print(sys)
# Out:
# <TransferFunction>: sys[2]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#             s + 2
#   --------------------------
#   500 s^3 + 1000 s^2 + s + 1
