# %%
import numpy as np
import matplotlib.pyplot as plt
import control as ct

m = 10; k = 1; b = 0.5
t = np.arange(0, 200, 0.1)

sys = ct.tf([1/m], [1, b/m, k/m])
pzmap = ct.pole_zero_map(sys)
# pzmap.plot()

T, out = sys.step_response(t)
plt.xlabel('t')
plt.ylabel('amp')
plt.grid(True)
plt.plot(T, out)
