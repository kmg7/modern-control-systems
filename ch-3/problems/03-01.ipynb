# %% [markdown]
# # Problem 03-01: Transfer Function to State-Space Conversion
#
# Using the `display_utils` module for LaTeX-formatted output.

# %%
import control as ct
import display_utils as dp

# %%
# a
sys_a = ct.tf([1], [1, 1])
ss_a = ct.ss(sys_a)
dp.tf(sys_a)
dp.ss(ss_a)
# Out:
# ### Transfer Function
# $\displaystyle G(s) = \frac{1}{s + 1}$
# ### State-Space System
# **System dimensions:** 1 states, 1 input(s), 1 output(s)
# **State-space equations:**
# $\displaystyle \dot{\mathbf{x}} = A\mathbf{x} + B\mathbf{u}$
# $\displaystyle \mathbf{y} = C\mathbf{x} + D\mathbf{u}$
# **System matrices:**
# $\displaystyle A = \left[\begin{matrix}-1\end{matrix}\right]$
# $\displaystyle B = \left[\begin{matrix}1\end{matrix}\right]$
# $\displaystyle C = \left[\begin{matrix}1\end{matrix}\right]$
# $\displaystyle D = \left[\begin{matrix}0\end{matrix}\right]$

# %%
# b
sys_b = ct.tf([1, 1, 1], [2, 1, 1])
ss_b = ct.ss(sys_b)
dp.ss(ss_b)
# Out:
# ### State-Space System
# **System dimensions:** 2 states, 1 input(s), 1 output(s)
# **State-space equations:**
# $\displaystyle \dot{\mathbf{x}} = A\mathbf{x} + B\mathbf{u}$
# $\displaystyle \mathbf{y} = C\mathbf{x} + D\mathbf{u}$
# **System matrices:**
# $\displaystyle A = \left[\begin{matrix}- \frac{1}{2} & \frac{1}{2}\\-1 & 0\end{matrix}\right]$
# $\displaystyle B = \left[\begin{matrix}1\\0\end{matrix}\right]$
# $\displaystyle C = \left[\begin{matrix}\frac{1}{4} & - \frac{1}{4}\end{matrix}\right]$
# $\displaystyle D = \left[\begin{matrix}\frac{1}{2}\end{matrix}\right]$

# %%
# c
sys_c = ct.tf([1, 1], [3, 2, 1, 1])
ss_c = ct.ss(sys_c)
dp.ss(ss_c)
# Out:
# ### State-Space System
# **System dimensions:** 3 states, 1 input(s), 1 output(s)
# **State-space equations:**
# $\displaystyle \dot{\mathbf{x}} = A\mathbf{x} + B\mathbf{u}$
# $\displaystyle \mathbf{y} = C\mathbf{x} + D\mathbf{u}$
# **System matrices:**
# $\displaystyle A = \left[\begin{matrix}- \frac{2}{3} & \frac{1}{3} & \frac{1}{3}\\-1 & 0 & 0\\0 & 1 & 0\end{matrix}\right]$
# $\displaystyle B = \left[\begin{matrix}-1\\0\\0\end{matrix}\right]$
# $\displaystyle C = \left[\begin{matrix}0 & \frac{1}{3} & \frac{1}{3}\end{matrix}\right]$
# $\displaystyle D = \left[\begin{matrix}0\end{matrix}\right]$
